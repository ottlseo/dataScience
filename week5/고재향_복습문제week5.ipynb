# %% [markdown]
# # 고재향벗 week5 복습문제
# ### Iris data를 바탕으로 꽃잎, 꽃받침의 길이, 너비를 통해 종류를 예측하기

# %%
import pandas as pd
df = pd.read_csv('data/Iris-Copy1.csv')
df['Species'][100]
# Out:
# 'Iris-virginica'

# %%
# string to int
df.loc[df['Species']=="Iris-setosa","Species"]=1
df.loc[df['Species']=="Iris-versicolor","Species"]=2
df.loc[df['Species']=='Iris-virginica',"Species"]=3
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0   1            5.1           3.5            1.4           0.2       1
# 1   2            4.9           3.0            1.4           0.2       1
# 2   3            4.7           3.2            1.3           0.2       1
# 3   4            4.6           3.1            1.5           0.2       1
# 4   5            5.0           3.6            1.4           0.2       1

# %%
my = df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
relation = my.corr()
relation
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# 히트맵으로 표현하기
plt.figure(figsize=(15,15))
sns.heatmap(relation, annot=True, fmt='.2f', square=True)
plt.show()

# %%
# 모델을 만들 x,y 값 지정
trainData = df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
targetData = df['Species']

# train : test = 7:3
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(trainData, targetData, test_size=0.3) #test_size 로 비율 정함

# %%
# 3. Linear Regression 모델 생성하기

from sklearn.linear_model import LinearRegression

lr = LinearRegression().fit(x_train, y_train) #train set으로 lr 모델 학습 시키기

print('train set score', lr.score(x_train, y_train))
print('test set score', lr.score(x_test, y_test))
# Out:
# train set score 0.9351965139321415
# test set score 0.9185018130291939

# %%
dbstjdi rhsocskgdk rhoscsgkddk? ektl ej dksqhc tn dlTsms tkfkaemfdlqslek rhoscks
gk ..........

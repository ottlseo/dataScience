# %% [markdown]
# # 마크다운 연습기
# ---
# 마크다운을 사용하면서 주피터 노트북과 친해져보겠습니다.
# 이 링크를 누르면 [코알라](https://coalastudy.com/feed)로 이동합니다.
#
# 여기서부터는 다른 문단입니다.
#
# ---
# ## 지금까지 배운 내용
# 마크다운으로 배운 내용
# 1. 큰 제목 넣기
# 2. 리스트 넣기
# 3. 표 넣기
# 4. 기타
#
# ---
# ## 정리
#
# 문법|사용법
# -|-
# 큰 제목| #을 사용
# 리스트| -혹은 1.을 사용
#
# ---
# ## 마무리
# 파이썬 코드로 Hello World 을 만들면서 끝내요.
# ```python
# print("Hello World!")
# ```

# %%
print("Hello World : )")
# Out:
# Hello World : )

# %% [markdown]
# ## 제작자
# **작성자** 김윤서
# **소속** 이화여자대학교 사이버보안전공
# ![이화여자대학교 사진](https://www.veritas-a.com/news/photo/202002/312713_212841_3933.jpg)
